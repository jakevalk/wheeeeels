# %% [markdown]
# # creating start stop array

# %%
# 180 rotations: 
array180 = [3965.2, 3966.8;
4103,4105.8;
4167,41685;
5438.5,5439.9;
6886,6887;
7721,7723]

array90 = [3967.5,3969;
4033.5,4034.5;
4035,4036.6;
7945,7946]
