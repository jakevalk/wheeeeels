# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # load and prep data

# %%
#load in data
Player = 9 
Game = 2

df_Player = pd.read_csv('matrix_Player_' + str(Player) + '_game_' + str(Game) + '_Action.csv')

# Fill NaN with 0 
df_Player = df_Player.fillna(0)

# trying to make sprinting 0 and 1 
for i in df_Player['Action']:
    if df_Player.Action[i] == 'Sprinting'  :       
        df_Player.Action[i] = 1
    else : 
            df_Player.Action[i] = 0
print(df_Player['Action'])
# Out:
# <ipython-input-48-7fe459642b5e>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_Player.Action[i] = 0
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-48-7fe459642b5e> in <module>
#      10 # trying to make sprinting 0 and 1
#      11 for i in df_Player['Action']:
# ---> 12     if df_Player.Action[i] == 'Sprinting'  :
#      13         df_Player.Action[i] = 1
#      14     else :
#
# /opt/jupyterhub/anaconda/lib/python3.8/site-packages/pandas/core/series.py in __getitem__(self, key)
#     851
#     852         elif key_is_scalar:
# --> 853             return self._get_value(key)
#     854
#     855         if is_hashable(key):
#
# ...

# %% [markdown]
# # convert data

# %%
#convert data into chunks of a second


n = 100 #chunk size (100 datapoints in one second)
df_Player_ML = [df_Player[i:i+n] for i in range(0,df_Player.shape[0],n)]

# %% [markdown]
# # split data

# %%
# split chunk data into train test validate (with colum [sum and Div] as input, and action as output)

#data = df_player_ML['Sum_WheelX_FrameZ', 'Div_FrameZ_WheelX', 'Action'].split(0.3, random_state=0).scalex()


data = 


print(data.head())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-f129b592948a> in <module>
#       1 # split chunk data into train test validate (with colum [sum and Div] as input, and action as output)
#       2
# ----> 3 data = df_player_ML['Sum_WheelX_FrameZ', 'Div_FrameZ_WheelX', 'Action'].split(0.3, random_state=0).scalex()
#       4 print(data.head())
#
# TypeError: list indices must be integers or slices, not tuple
