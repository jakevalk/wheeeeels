# %%
# !git pull
# Out:
# error: You have not concluded your merge (MERGE_HEAD exists).
# hint: Please, commit your changes before merging.
# fatal: Exiting because of unfinished merge.

# %%
# !git add .

# %%
# !git commit -m "Test"
# Out:
# [master af04749] Test
#  Committer: jakevalk <18064396@datascience.hhs.nl>
# Your name and email address were configured automatically based
# on your username and hostname. Please check that they are accurate.
# You can suppress this message by setting them explicitly:
#
#     git config --global user.name "Your Name"
#     git config --global user.email you@example.com
#
# After doing this, you may fix the identity used for this commit with:
#
#     git commit --amend --reset-author

# %%
# !git push https://jakevalk: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@github.com/jakevalk/wheeeeels.git --all
# Out:
# Counting objects: 60, done.
# Delta compression using up to 48 threads.
# Compressing objects: 100% (60/60), done.
# Writing objects: 100% (60/60), 56.33 MiB | 3.29 MiB/s, done.
# Total 60 (delta 33), reused 0 (delta 0)
# remote: Resolving deltas: 100% (33/33), completed with 7 local objects.
# remote: warning: File Daan/matrix_Player_9_game_2_Action.csv is 94.90 MB; this is larger than GitHub's recommended maximum file size of 50.00 MB
# remote: error: Trace: 27c6308598ee1e00b2e3558fd2b94953fa942b4917c0a7a5082730b857296067
# remote: error: See http://git.io/iEPt8g for more information.
# remote: error: File Martijn/matrix_Player_9_game_2_All_Action.csv is 122.49 MB; this exceeds GitHub's file size limit of 100.00 MB
# remote: error: File Daan/matrix_Player_9_game_2_Action_2.0.csv is 122.41 MB; this exceeds GitHub's file size limit of 100.00 MB
# remote: error: GH001: Large files detected. You may want to try Git Large File Storage - https://git-lfs.github.com.
# ...
