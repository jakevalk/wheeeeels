# %% [markdown]
# I tried to do a few arrays

# %%
import numpy as np
np_array = np.array([1,2,3,4,5,6,7,8])
print(np_array)
# Out:
# [1 2 3 4 5 6 7 8]

# %%
np_array2 = np.array([5,6,7,8,9])
print(np_array2)
# Out:
# [5 6 7 8 9]

# %% [markdown]
# here i tried to import a csv dataset

# %%
import pandas as pd
df = pd.read_csv('Ned - DUI Game 1.csv')
print(df.head())
# Out:
#                     Name  Position  Duration           Player  \
# 0         Off court (11)   4468800      1000        Off court
# 1         Off court (10)   4468800      1000        Off court
# 2                2P (46)   4464400      2000              NaN
# 3  Contact stopped (121)   4458320      1000  Contact stopped
# 4     Fast defence (139)   4455280      1000     Fast defence
#
#   Players Group Box Game time Scoring Team Misc Actions Score
# 0         Player 15       NaN     NaN  NaN          NaN   NaN
# 1          Player 6       NaN     NaN  NaN          NaN   NaN
# 2               NaN   Defence      2P  NaN          NaN   NaN
# 3          Player 1       NaN     NaN  NaN          NaN   NaN
# 4         Player 10       NaN     NaN  NaN          NaN   NaN

# %%
print(df[['Name', 'Players Group Box']])
# Out:
#                         Name Players Group Box
# 0             Off court (11)         Player 15
# 1             Off court (10)          Player 6
# 2                    2P (46)               NaN
# 3      Contact stopped (121)          Player 1
# 4         Fast defence (139)         Player 10
# ...                      ...               ...
# 1050  Contact IS stopped (1)         Player 14
# 1051            On court (3)         Player 15
# 1052            On court (2)          Player 6
# 1053            On court (1)          Player 2
# 1054            No clock (1)               NaN
#
# [1055 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
plt.plot(df[['Position']], df[['Duration']])
plt.show()
