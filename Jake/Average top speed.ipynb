# %%
print("average top speed goes brrrrrrrr")
# Out:
# average top speed goes brrrrrrrr

# %% [markdown]
# # Here we are going to calculate the average sprint speed

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.signal import find_peaks

df = pd.read_csv('matrix_player_6.csv')
df = df.fillna(0)

# %%
length = int(len(df['timeLine']) * 0.02)
temp = df.iloc[:length, :]

# %%
for index in range(length) :
    if df.loc[index, [' frameRotationalSpeedZ ']].values > 5 or df.loc[index, [' frameRotationalSpeedZ ']].values < -5 :
        temp = temp.drop(index, axis=0)

# %%
peakDistance = 1000

# %%
peaks, _ = find_peaks(temp.loc[:len(temp), 'wheelRotationalSpeedX '], distance=peakDistance)

meanPeak = peaks.mean()
medianPeak = peaks.median()
print(meanPeak)
print(medianPeak)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-2446138df0f4> in <module>
#       2
#       3 meanPeak = peaks.mean()
# ----> 4 medianPeak = peaks.median()
#       5 print(meanPeak)
#       6 print(medianPeak)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'median'
