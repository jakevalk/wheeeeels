# %%
# Import necessary modules
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_iris
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_player = pd.read_csv('matrix_Player_6_game_1.csv')
df_player = df_player.fillna(0)

# %%
print(df_player.loc[:2000, ['frameRotationalSpeedX', 'wheelRotationalSpeedX']])
# Out:
#       frameRotationalSpeedX  wheelRotationalSpeedX
# 0                  -0.28000                0.70000
# 1                  -0.35000                0.82250
# 2                  -0.33444                0.77000
# 3                  -0.28000                0.88375
# 4                  -0.30100                0.77000
# ...                     ...                    ...
# 1996               -0.35000                0.78750
# 1997               -0.35000                0.73500
# 1998               -0.28000                0.74375
# 1999               -0.21778                0.80111
# 2000               -0.28000                0.87500
#
# [2001 rows x 2 columns]

# %%
sprints = [0]*770883 #make an array of 770883 empty values
for i in range(770883) :
    spd = df_player.loc[i,'frSpeed'] #almaceno datos del dataset, en la posición x para la columna frSpeed en spd
    acc = df_player.loc[i,'frAcc'] #almaceno datos del dataset, en la posición x para la columna frSpeed en spd
    if spd > 1 and acc > 10 :#si la velocidad es >3 y acc>10 isSprinting
        sprints[i] = 1#if value is 1 its sprinting if it isnt its not sprinting

df_player["IsSprinting"] = sprints
print(df_player["IsSprinting"] == 1)

y= df_player["IsSprinting"]#one column same rows
#quitamos la columna is sprinting de la tabla
x= df_player[['frAcc', 'frSpeed']]#x has to have same number of rows more columns
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 770878    False
# 770879    False
# 770880    False
# 770881    False
# 770882    False
# Name: IsSprinting, Length: 770883, dtype: bool

# %%
# Split into training and test set(preparamos el modelo)
X_train, X_test, y_train, y_test = train_test_split(
             x, y, random_state=0)#por defecto un 75% de los datos es para train y el 25 restante para test
print(y_train)
# Out:
# 710182    0
# 266294    0
# 654866    0
# 242759    0
# 582598    0
#          ..
# 359783    0
# 152315    0
# 117952    0
# 435829    0
# 305711    0
# Name: IsSprinting, Length: 578162, dtype: int64

# %%
neighbors = np.arange(1, 7)#create an array from 1 to 7 

train_accuracy = np.empty(len(neighbors))#both are random value arrays
test_accuracy = np.empty(len(neighbors))#with a length of 7
 
    
knn = KNeighborsClassifier(n_neighbors=7)
    
knn.fit(X_train, y_train)
# Out:
# a

# %%
# Loop over K values to see wich model fits the best
for i, k in enumerate(neighbors):# is the index and k the value of the array neighbors
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train, y_train)
    
    train_accuracy[i] = knn.score(X_train, y_train)
    test_accuracy[i] = knn.score(X_test, y_test)
#We get the accuracy of the training and test models

         
# Compute training and test data accuracy


plt.plot(neighbors, test_accuracy, label = 'Testing dataset Accuracy')
plt.plot(neighbors, train_accuracy, label = 'Training dataset Accuracy')
     
    
plt.legend()
plt.xlabel('n_neighbors')
plt.ylabel('Accuracy')
plt.show()

# %%
#FROM HERE TO THE END ITS TRIALS (NOT WORKING)







# Split into training and test set
X_train, X_test, y_train, y_test = train_test_split(
             x, y, random_state=0)#por defecto un 75% de los datos es para train y el 25 restante para test

neighbors = np.arange(1, 100)#create an array from 1 to 199

train_accuracy = np.empty(len(neighbors))#both are random value arrays
test_accuracy = np.empty(len(neighbors))#with a length of 200
 

# Loop over K values to see wich model fits the best
for i, k in enumerate(neighbors):# is the index and k the value of the array neighbors
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train, y_train)#here comes the problem

         
# Compute training and test data accuracy
train_accuracy[i] = knn.score(X_train, y_train)
test_accuracy[i] = knn.score(X_test, y_test)
 
# Generate plot(til here doesnt work)
plt.plot(neighbors, test_accuracy, label = 'Testing dataset Accuracy')
plt.plot(neighbors, train_accuracy, label = 'Training dataset Accuracy')
 
plt.legend()
plt.xlabel('n_neighbors')
plt.ylabel('Accuracy')
plt.show()

# %% [markdown]
# Example(doesn't work)

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.datasets import load_breast_cancer
from sklearn.metrics import confusion_matrix
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
import seaborn as sns
sns.set()

x=irisData.data
y=irisData.target
X_train, X_test, y_train, y_test = train_test_split(
             x, y, test_size = 0.2, random_state=42)
print(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-35c69029ca5e> in <module>
#       9 sns.set()
#      10
# ---> 11 x=irisData.data
#      12 y=irisData.target
#      13 X_train, X_test, y_train, y_test = train_test_split(
#
# NameError: name 'irisData' is not defined

# %%
print(y)
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 770878    0
# 770879    0
# 770880    0
# 770881    0
# 770882    0
# Name: IsSprinting, Length: 770883, dtype: int64

# %%
# Split into training and test set
X_train, X_test, y_train, y_test = train_test_split(
             x, y, test_size = 0.2, random_state=42)

neighbors = np.arange(1, 9)
train_accuracy = np.empty(len(neighbors))
test_accuracy = np.empty(len(neighbors))
 
# Loop over K values
for i, k in enumerate(neighbors):
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train, y_train)
     
    # Compute training and test data accuracy
    train_accuracy[i] = knn.score(X_train, y_train)
    test_accuracy[i] = knn.score(X_test, y_test)
 
# Generate plot
plt.plot(neighbors, test_accuracy, label = 'Testing dataset Accuracy')
plt.plot(neighbors, train_accuracy, label = 'Training dataset Accuracy')
 
plt.legend()
plt.xlabel('n_neighbors')
plt.ylabel('Accuracy')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-b958b7ed3b7f> in <module>
#      13
#      14     # Compute training and test data accuracy
# ---> 15     train_accuracy[i] = knn.score(X_train, y_train)
#      16     test_accuracy[i] = knn.score(X_test, y_test)
#      17
#
# /opt/jupyterhub/anaconda/lib/python3.8/site-packages/sklearn/base.py in score(self, X, y, sample_weight)
#     498         """
#     499         from .metrics import accuracy_score
# --> 500         return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#     501
#     502     def _more_tags(self):
#
# /opt/jupyterhub/anaconda/lib/python3.8/site-packages/sklearn/neighbors/_classification.py in predict(self, X)
#     209         for k, classes_k in enumerate(classes_):
#     210             if weights is None:
# --> 211                 mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
#     212             else:
#     213                 mode, _ = weighted_mode(_y[neigh_ind, k], weights, axis=1)
#
# /opt/jupyterhub/anaconda/lib/python3.8/site-packages/scipy/stats/stats.py in mode(a, axis, nan_policy)
#     570     counts = np.empty(a_view.shape[:-1], dtype=np.int_)
#     571     for ind in inds:
# --> 572         modes[ind], counts[ind] = _mode1D(a_view[ind])
#     573     newshape = list(a.shape)
#     574     newshape[axis] = 1
#
# /opt/jupyterhub/anaconda/lib/python3.8/site-packages/scipy/stats/stats.py in _mode1D(a)
#     558     def _mode1D(a):
#     559         vals, cnts = np.unique(a, return_counts=True)
# --> 560         return vals[cnts.argmax()], cnts.max()
#     561
#     562     # np.apply_along_axis will convert the _mode1D tuples to a numpy array, casting types in the process
#
# /opt/jupyterhub/anaconda/lib/python3.8/site-packages/numpy/core/_methods.py in _amax(a, axis, out, keepdims, initial, where)
#      37 def _amax(a, axis=None, out=None, keepdims=False,
#      38           initial=_NoValue, where=True):
# ---> 39     return umr_maximum(a, axis, None, out, keepdims, initial, where)
#      40
#      41 def _amin(a, axis=None, out=None, keepdims=False,
#
# KeyboardInterrupt:
