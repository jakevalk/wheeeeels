# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # load and prep data

# %%
#load in df
Player = 9 
Game = 2

df = pd.read_csv('matrix_Player_' + str(Player) + '_game_' + str(Game) + '_Action.csv')

# Fill NaN with 0 
df = df.fillna(0)

#Convert Sprinting to 1
df.Action[df.Action == "Sprinting"] = 1

#Delete first 99 rows, so df starts at timeLine == 1.00
df = df.iloc[99: , :]

df
# Out:
# /opt/jupyterhub/anaconda/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3169: DtypeWarning: Columns (16) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# <ipython-input-21-ff79a9649b8e>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Action[df.Action == "Sprinting"] = 1
#         Unnamed: 0     frAcc      frRoAcc    frDispl  frRoAng   frSpeed  \
# 99              99 -0.036607     0.001674    -1.6355 -0.58432  0.007447
# 100            100 -0.197150     0.001747    -1.6333  1.02820  0.007081
# 101            101 -0.116860     0.001808    -1.6167  2.27630  0.005109
# 102            102 -0.170020     0.001853    -1.5874  3.59700  0.003941
# 103            103 -0.127920     0.001884    -1.5460  4.67560  0.002241
# ...            ...       ...          ...        ...      ...       ...
# 754220      754220 -0.030424  4981.900000  6585.3000 -0.11980 -0.001860
# 754221      754221  0.062668  4981.900000  6585.3000 -0.11723 -0.002164
# 754222      754222  0.019899  4981.900000  6585.2000 -0.13407 -0.001537
# 754223      754223  0.000000     0.000000     0.0000  0.00000  0.000000
# 754224      754224  0.000000     0.000000     0.0000  0.00000  0.000000
#
#         timeLine  frameRotationalSpeedX  frameRotationalSpeedY  \
# 99          1.00                1.14800                 2.8980
# 100         1.01                1.24600                 3.0240
# 101         1.02                1.36110                 3.2744
# 102         1.03                1.40000                 3.4738
# 103         1.04                1.35100                 3.5980
# ...          ...                    ...                    ...
# 754220   7542.20                0.97222                 2.4578
# 754221   7542.20                0.91000                 2.5480
# 754222   7542.20                0.92400                 2.6320
# 754223      0.00                0.96444                 2.5200
# 754224      0.00                0.88375                 2.5200
#
#         frameRotationalSpeedZ  wheelRotationalSpeedX  wheelRotationalSpeedY  \
# 99                   -1.41400               2.068900                 6.1911
# 100                  -0.01400               0.518000                 5.0470
# 101                   1.22890              -0.980000                 4.1370
# 102                   2.54630              -2.403300                 3.2900
# 103                   3.62600              -3.697300                 2.6155
# ...                       ...                    ...                    ...
# 754220               -0.98778              -0.000000                 4.6900
# 754221               -1.05000              -0.056000                 4.4940
# 754222               -1.05000               0.070000                 4.6200
# 754223               -1.01890               0.070000                 4.6200
# 754224               -0.93625               0.081667                 4.5850
#
#         wheelRotationalSpeedZ  frRoSpeed  Sum_WheelX_FrameZ  \
# 99                     4.2389  161.25000           0.654900
# 100                    3.3460  124.81000           0.504000
# 101                    2.3450  132.07000           0.248900
# 102                    1.3067  107.86000           0.143000
# 103                    0.4200   89.30900          -0.071300
# ...                       ...        ...                ...
# 754220                 2.7300    0.25656          -0.987780
# 754221                 2.5970   -1.68370          -1.106000
# 754222                 2.6600    0.00000          -0.980000
# 754223                 2.6600    0.00000          -0.948900
# 754224                 2.6250    0.00000          -0.854583
#
#         Div_FrameZ_WheelX Action
# 99              -0.683455      0
# 100             -0.027027      0
# 101             -1.253980      0
# 102             -1.059502      0
# 103             -0.980716      0
# ...                   ...    ...
# 754220                inf      0
# 754221          18.750000      0
# 754222         -15.000000      0
# 754223         -14.555714      0
# 754224         -11.464239      0
#
# [754126 rows x 17 columns]

# %% [markdown]
# # convert data

# %%
#Convert data into chunks of a second
n = 100 #chunk size (100 datapoints in one second)
chunks = [df[i:i+n] for i in range(0,df.shape[0],n)]

#Set chunks into dataframe
df = pd.DataFrame(chunks)
df
# Out:
# /opt/jupyterhub/anaconda/lib/python3.8/site-packages/pandas/core/internals/construction.py:309: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   values = np.array([convert(v) for v in values])
#                                                       0
# 0          Unnamed: 0     frAcc   frRoAcc   frDispl ...
# 1          Unnamed: 0     frAcc   frRoAcc   frDispl ...
# 2          Unnamed: 0     frAcc   frRoAcc  frDispl  ...
# 3          Unnamed: 0     frAcc   frRoAcc  frDispl  ...
# 4          Unnamed: 0     frAcc   frRoAcc  frDispl  ...
# ...                                                 ...
# 7537          Unnamed: 0     frAcc  frRoAcc  frDispl...
# 7538          Unnamed: 0    frAcc  frRoAcc  frDispl ...
# 7539          Unnamed: 0     frAcc  frRoAcc  frDispl...
# 7540          Unnamed: 0     frAcc  frRoAcc  frDispl...
# 7541          Unnamed: 0     frAcc  frRoAcc  frDispl...
#
# [7542 rows x 1 columns]

# %% [markdown]
# # split data

# %%
# split chunk data into train test validate (with colum [sum and Div] as input, and action as output)

#data = df_player_ML['Sum_WheelX_FrameZ', 'Div_FrameZ_WheelX', 'Action'].split(0.3, random_state=0).scalex()


data = 


print(data.head())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-f129b592948a> in <module>
#       1 # split chunk data into train test validate (with colum [sum and Div] as input, and action as output)
#       2
# ----> 3 data = df_player_ML['Sum_WheelX_FrameZ', 'Div_FrameZ_WheelX', 'Action'].split(0.3, random_state=0).scalex()
#       4 print(data.head())
#
# TypeError: list indices must be integers or slices, not tuple
